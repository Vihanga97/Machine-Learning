# %%
import tensorflow as tf
import numpy as np
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_test,y_test)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 8s 1us/step

# %%
x_train=tf.keras.utils.normalize(x_train, axis=1)
x_test=tf.keras.utils.normalize(x_test, axis=1)

model=tf.keras.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 9s 151us/sample - loss: 0.2644 - accuracy: 0.9219
# Epoch 2/10
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.1069 - accuracy: 0.9663
# Epoch 3/10
# 60000/60000 [==============================] - 6s 92us/sample - loss: 0.0734 - accuracy: 0.9769
# Epoch 4/10
# 60000/60000 [==============================] - 6s 92us/sample - loss: 0.0541 - accuracy: 0.9828
# Epoch 5/10
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.0404 - accuracy: 0.9870
# Epoch 6/10
# 60000/60000 [==============================] - 6s 92us/sample - loss: 0.0327 - accuracy: 0.9890
# Epoch 7/10
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.0277 - accuracy: 0.9907
# Epoch 8/10
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.0210 - accuracy: 0.9930
# Epoch 9/10
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.0181 - accuracy: 0.9939
# Epoch 10/10
# 60000/60000 [==============================] - 6s 93us/sample - loss: 0.0143 - accuracy: 0.9951

# %%
val_loss, val_accu = model.evaluate(x_test, y_test)
print(val_loss, val_accu)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# 0.10644976737749584 0.9752

# %%
prediction=model.predict([x_test])
print(prediction)
# Out:
# [[4.1731533e-13 3.7518072e-10 5.7891164e-11 ... 1.0000000e+00
#   2.6533411e-13 2.7034220e-11]
#  [3.6323446e-16 5.5055800e-09 1.0000000e+00 ... 2.6690430e-15
#   1.2662372e-15 8.8654910e-24]
#  [2.8670213e-12 9.9999988e-01 1.6669712e-09 ... 9.8253437e-08
#   2.1038527e-08 2.3346994e-11]
#  ...
#  [5.6029048e-15 1.0623334e-12 1.0739454e-13 ... 2.2999885e-08
#   1.9126489e-10 4.6049323e-07]
#  [4.9562823e-11 1.8215207e-11 5.8871789e-11 ... 6.2821016e-12
#   6.0943324e-07 1.2360556e-14]
#  [7.4719683e-14 2.0378084e-17 7.0603722e-16 ... 4.6704941e-20
#   3.7060433e-12 1.6732009e-18]]

# %%
print (np.argmax(prediction[1997]))
# Out:
# 3

# %%
import matplotlib.pyplot as plt
plt.imshow(x_test[1997])
plt.show()
